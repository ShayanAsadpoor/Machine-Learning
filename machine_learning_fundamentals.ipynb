# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Access the file
file_path = "/content/drive/MyDrive/kc_house_data_NaN.csv"

# %%
data = pd.read_csv(file_path)
data
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0               0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1               1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2               2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3               3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4               4  1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...         ...              ...       ...       ...        ...
# 21608       21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609       21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610       21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611       21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612       21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     21613 non-null  int64
#  1   id             21613 non-null  int64
#  2   date           21613 non-null  object
#  3   price          21613 non-null  float64
#  4   bedrooms       21600 non-null  float64
#  5   bathrooms      21603 non-null  float64
#  6   sqft_living    21613 non-null  int64
#  7   sqft_lot       21613 non-null  int64
#  8   floors         21613 non-null  float64
#  9   waterfront     21613 non-null  int64
#  10  view           21613 non-null  int64
#  11  condition      21613 non-null  int64
#  12  grade          21613 non-null  int64
#  13  sqft_above     21613 non-null  int64
#  14  sqft_basement  21613 non-null  int64
#  15  yr_built       21613 non-null  int64
#  16  yr_renovated   21613 non-null  int64
# ...

# %% [markdown]
# Filling Nan, dropping unusable cols and making all of them numerical

# %%
dropping_cols = ["Unnamed: 0", "id", "sqft_living15", "sqft_lot15"]

data = data.drop(columns=dropping_cols)
data
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900.0       3.0       1.00         1180      5650
# 1      20141209T000000  538000.0       3.0       2.25         2570      7242
# 2      20150225T000000  180000.0       2.0       1.00          770     10000
# 3      20141209T000000  604000.0       4.0       3.00         1960      5000
# 4      20150218T000000  510000.0       3.0       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 21608  20140521T000000  360000.0       3.0       2.50         1530      1131
# 21609  20150223T000000  400000.0       4.0       2.50         2310      5813
# 21610  20140623T000000  402101.0       2.0       0.75         1020      1350
# 21611  20150116T000000  400000.0       3.0       2.50         1600      2388
# 21612  20141015T000000  325000.0       2.0       0.75         1020      1076
#
# ...

# %%
nan_indexes = data[data['date'].isna()].index
nan_indexes
# Out:
# Int64Index([], dtype='int64')

# %%
data['date'] = data['date'].str.extract('(\d{8})')
data
# Out:
#            date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      20141013  221900.0       3.0       1.00         1180      5650     1.0
# 1      20141209  538000.0       3.0       2.25         2570      7242     2.0
# 2      20150225  180000.0       2.0       1.00          770     10000     1.0
# 3      20141209  604000.0       4.0       3.00         1960      5000     1.0
# 4      20150218  510000.0       3.0       2.00         1680      8080     1.0
# ...         ...       ...       ...        ...          ...       ...     ...
# 21608  20140521  360000.0       3.0       2.50         1530      1131     3.0
# 21609  20150223  400000.0       4.0       2.50         2310      5813     2.0
# 21610  20140623  402101.0       2.0       0.75         1020      1350     2.0
# 21611  20150116  400000.0       3.0       2.50         1600      2388     2.0
# 21612  20141015  325000.0       2.0       0.75         1020      1076     2.0
#
# ...

# %%
data['date'] = data['date'].str.extract('(\d{4})').astype(int)
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-54343c31a173> in <cell line: 1>()
# ----> 1 data['date'] = data['date'].str.extract('(\d{4})').astype(int)
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
# ...

# %%
nan_indexes = data[data['bedrooms'].isna()].index
nan_indexes
# Out:
# Int64Index([875, 3119, 3467, 4868, 6994, 8477, 8484, 9773, 9854, 12653, 14423,
#             18379, 19452],
#            dtype='int64')

# %%
median_value = data['bedrooms'].median()
data['bedrooms'].fillna(median_value, inplace=True)

# %%
nan_indexes = data[data['bathrooms'].isna()].index
nan_indexes
# Out:
# Int64Index([875, 1149, 3119, 5832, 6994, 9773, 9854, 10481, 14423, 19452], dtype='int64')

# %%
bath_median_value = data["bathrooms"].median()
data['bathrooms'].fillna(bath_median_value, inplace = True)

# %%
living_mean_value = data['sqft_living'].mean()
data['sqft_living'].fillna(living_mean_value, inplace=True)

# %%
# nan_indexes = data[data['sqft_lot15'].isna()].index
# nan_indexes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  int64
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  float64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %% [markdown]
# Finding the Outliers

# %%
data
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2014  221900.0       3.0       1.00         1180      5650     1.0
# 1      2014  538000.0       3.0       2.25         2570      7242     2.0
# 2      2015  180000.0       2.0       1.00          770     10000     1.0
# 3      2014  604000.0       4.0       3.00         1960      5000     1.0
# 4      2015  510000.0       3.0       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608  2014  360000.0       3.0       2.50         1530      1131     3.0
# 21609  2015  400000.0       4.0       2.50         2310      5813     2.0
# 21610  2014  402101.0       2.0       0.75         1020      1350     2.0
# 21611  2015  400000.0       3.0       2.50         1600      2388     2.0
# 21612  2014  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
# Count the number of occurrences of each bedroom value
bedroom_counts = data["bedrooms"].value_counts()

# Sort the counts by the bedroom values
bedroom_counts = bedroom_counts.sort_index()

# Create a bar plot
plt.figure(figsize=(20, 6))  # Optional: Adjust the figure size
plt.bar(bedroom_counts.index, bedroom_counts.values, tick_label=bedroom_counts.index)

# Add labels and title
plt.xlabel('Number of Bedrooms')
plt.ylabel('Count')
plt.title('Number of Bedrooms Distribution')

# Show the plot
plt.show()

# %%
bedroom_counts
# Out:
# 1.0      199
# 2.0     2760
# 3.0     9837
# 4.0     6882
# 5.0     1601
# 6.0      272
# 7.0       38
# 8.0       13
# 9.0        6
# 10.0       3
# 11.0       1
# 33.0       1
# Name: bedrooms, dtype: int64

# %%
# Replace 'x_column' and 'y_column' with the actual names of the columns you want to plot
x_column = 'bedrooms'
y_column = 'sqft_living'

# Create a scatter plot
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
plt.scatter(data[x_column], data[y_column])

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot')

# Show the plot
plt.show()

# %%
# Replace 'bedrooms' with the actual name of your 'bedrooms' column
bedrooms_column = 'bedrooms'

# Create a new DataFrame without rows where 'bedrooms' is equal to 33
data = data[data[bedrooms_column] != 33]

# %%
# Count the number of occurrences of each bedroom value
bedroom_counts = data["bedrooms"].value_counts()

# Sort the counts by the bedroom values
bedroom_counts = bedroom_counts.sort_index()

# Create a bar plot
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
plt.bar(bedroom_counts.index, bedroom_counts.values, tick_label=bedroom_counts.index)

# Add labels and title
plt.xlabel('Number of Bedrooms')
plt.ylabel('Count')
plt.title('Number of Bedrooms Distribution')

# Show the plot
plt.show()

# %%
# Count the number of occurrences of each bedroom value
bedroom_counts = data["bathrooms"].value_counts()

# Sort the counts by the bedroom values
bedroom_counts = bedroom_counts.sort_index()

# Create a bar plot
plt.figure(figsize=(20, 6))  # Optional: Adjust the figure size
plt.bar(bedroom_counts.index, bedroom_counts.values, tick_label=bedroom_counts.index)

# Add labels and title
plt.xlabel('Number of Bedrooms')
plt.ylabel('Count')
plt.title('Number of Bedrooms Distribution')

# Show the plot
plt.show()

# %%
# Replace 'x_column' and 'y_column' with the actual names of the columns you want to plot
x_column = 'bedrooms'
y_column = 'bathrooms'

# Create a scatter plot
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
plt.scatter(data[x_column], data[y_column])

# Add labels and title
plt.xlabel('bedrooms')
plt.ylabel('bathrooms')
plt.title('Scatter Plot')

# Show the plot
plt.show()

# %%
# Replace 'bedrooms_column' and 'bathrooms_column' with the actual column names in your dataset
bedrooms_column = 'bedrooms'
bathrooms_column = 'bathrooms'

# Calculate the bedroom-to-bathroom ratio and add it as a new column
data['bedroom_to_bathroom_ratio'] = data[bedrooms_column] / data[bathrooms_column]

# Print the DataFrame to see the added column
data[['bedrooms', 'bathrooms', 'bedroom_to_bathroom_ratio']].head()
# Out:
# <ipython-input-212-a7a0c77ba7b9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bedroom_to_bathroom_ratio'] = data[bedrooms_column] / data[bathrooms_column]
#    bedrooms  bathrooms  bedroom_to_bathroom_ratio
# 0       3.0       1.00                   3.000000
# 1       3.0       2.25                   1.333333
# 2       2.0       1.00                   2.000000
# 3       4.0       3.00                   1.333333
# 4       3.0       2.00                   1.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21612 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       21612 non-null  int64
#  1   price                      21612 non-null  float64
#  2   bedrooms                   21612 non-null  float64
#  3   bathrooms                  21612 non-null  float64
#  4   sqft_living                21612 non-null  int64
#  5   sqft_lot                   21612 non-null  int64
#  6   floors                     21612 non-null  float64
#  7   waterfront                 21612 non-null  int64
#  8   view                       21612 non-null  int64
#  9   condition                  21612 non-null  int64
#  10  grade                      21612 non-null  int64
#  11  sqft_above                 21612 non-null  int64
#  12  sqft_basement              21612 non-null  int64
# ...

# %%
ratio_counts = data["bedroom_to_bathroom_ratio"].value_counts()

ratio_counts = ratio_counts.sort_index()
print(ratio_counts)
# Out:
# 0.400000     2
# 0.444444     7
# 0.500000     6
# 0.571429     5
# 0.615385     8
#             ..
# 5.000000    44
# 5.333333     2
# 6.000000     6
# 7.000000     1
# 8.000000     1
# Name: bedroom_to_bathroom_ratio, Length: 86, dtype: int64

# %%
# Define the conditions
condition = (data["bedroom_to_bathroom_ratio"] >= 4.5) | (data["bedroom_to_bathroom_ratio"] < 0.5)

# Count the number of entries that meet the conditions
count_entries = len(data[condition])

# Print the count
print("Number of entries with ratio > 6 and < 0.35:", count_entries)
# Out:
# Number of entries with ratio > 6 and < 0.35: 65

# %%
df_filtered = data[condition]
df_filtered
# Out:
#        date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 950    2015   435000.0       5.0       1.00         1410      6750     1.5
# 1149   2015    75000.0       1.0       2.25          670     43377     1.0
# 1811   2014   300000.0       5.0       1.00         1940      8875     1.0
# 2003   2014   560000.0       5.0       1.00         1710      9100     1.5
# 2241   2015  1000000.0       5.0       1.00         2010      5210     1.5
# ...     ...        ...       ...        ...          ...       ...     ...
# 17875  2015   642000.0       6.0       1.00         1530      4305     1.5
# 18290  2014   397000.0       5.0       1.00         1170      6757     1.0
# 18527  2014   220000.0       5.0       1.00         1260      8382     1.5
# 18677  2014   262000.0       5.0       1.00         1870      7800     1.0
# 19086  2014   774900.0       5.0       1.00         1750      3861     1.5
#
# ...

# %%
# Define the conditions
condition = ~((data["bedroom_to_bathroom_ratio"] >= 4.5) | (data["bedroom_to_bathroom_ratio"] < 0.5))

# Count the number of entries that meet the conditions
# count_entries = len(data[condition])
data = data[condition]
data
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2014  221900.0       3.0       1.00         1180      5650     1.0
# 1      2014  538000.0       3.0       2.25         2570      7242     2.0
# 2      2015  180000.0       2.0       1.00          770     10000     1.0
# 3      2014  604000.0       4.0       3.00         1960      5000     1.0
# 4      2015  510000.0       3.0       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608  2014  360000.0       3.0       2.50         1530      1131     3.0
# 21609  2015  400000.0       4.0       2.50         2310      5813     2.0
# 21610  2014  402101.0       2.0       0.75         1020      1350     2.0
# 21611  2015  400000.0       3.0       2.50         1600      2388     2.0
# 21612  2014  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
Q1 = data['sqft_living'].quantile(.25)
Q3 = data['sqft_living'].quantile(.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to keep only rows within the bounds
data = data[(data['sqft_living'] >= lower_bound) & (data['sqft_living'] <= upper_bound)]

data
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2014  221900.0       3.0       1.00         1180      5650     1.0
# 1      2014  538000.0       3.0       2.25         2570      7242     2.0
# 2      2015  180000.0       2.0       1.00          770     10000     1.0
# 3      2014  604000.0       4.0       3.00         1960      5000     1.0
# 4      2015  510000.0       3.0       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608  2014  360000.0       3.0       2.50         1530      1131     3.0
# 21609  2015  400000.0       4.0       2.50         2310      5813     2.0
# 21610  2014  402101.0       2.0       0.75         1020      1350     2.0
# 21611  2015  400000.0       3.0       2.50         1600      2388     2.0
# 21612  2014  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
Q1 = data['sqft_lot'].quantile(.25)
Q3 = data['sqft_lot'].quantile(.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to keep only rows within the bounds
data = data[(data['sqft_lot'] >= lower_bound) & (data['sqft_lot'] <= upper_bound)]

data
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2014  221900.0       3.0       1.00         1180      5650     1.0
# 1      2014  538000.0       3.0       2.25         2570      7242     2.0
# 2      2015  180000.0       2.0       1.00          770     10000     1.0
# 3      2014  604000.0       4.0       3.00         1960      5000     1.0
# 4      2015  510000.0       3.0       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608  2014  360000.0       3.0       2.50         1530      1131     3.0
# 21609  2015  400000.0       4.0       2.50         2310      5813     2.0
# 21610  2014  402101.0       2.0       0.75         1020      1350     2.0
# 21611  2015  400000.0       3.0       2.50         1600      2388     2.0
# 21612  2014  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
Q1 = data['sqft_above'].quantile(.25)
Q3 = data['sqft_above'].quantile(.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to keep only rows within the bounds
data = data[(data['sqft_above'] >= lower_bound) & (data['sqft_above'] <= upper_bound)]

data
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2014  221900.0       3.0       1.00         1180      5650     1.0
# 1      2014  538000.0       3.0       2.25         2570      7242     2.0
# 2      2015  180000.0       2.0       1.00          770     10000     1.0
# 3      2014  604000.0       4.0       3.00         1960      5000     1.0
# 4      2015  510000.0       3.0       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608  2014  360000.0       3.0       2.50         1530      1131     3.0
# 21609  2015  400000.0       4.0       2.50         2310      5813     2.0
# 21610  2014  402101.0       2.0       0.75         1020      1350     2.0
# 21611  2015  400000.0       3.0       2.50         1600      2388     2.0
# 21612  2014  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
# Check if any row has a zipcode value of 0
has_zero_zipcode = (data["zipcode"] == 0).any()

# Print the result
if has_zero_zipcode:
    print("There is at least one row with a zipcode value of 0.")
else:
    print("There are no rows with a zipcode value of 0.")

# So All the zipcodes are valid
# Out:
# There are no rows with a zipcode value of 0.

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler


# Select the 'latitude' and 'longitude' columns
coordinates = data[['lat', 'long']]

# Standardize the coordinates (scaling)
scaler = StandardScaler()
scaled_coordinates = scaler.fit_transform(coordinates)

# Initialize DBSCAN
epsilon = 0.1  # Epsilon value for the neighborhood
min_samples = 5  # Minimum number of samples in a neighborhood to be considered a core point
dbscan = DBSCAN(eps=epsilon, min_samples=min_samples, metric='euclidean')

# Fit DBSCAN to the scaled coordinates
labels = dbscan.fit_predict(scaled_coordinates)

# Add the cluster labels back to the original DataFrame
data['cluster_label'] = labels

# Display the resulting clusters
data[['lat', 'long', 'cluster_label']]
# Out:
# <ipython-input-222-7c120cb9164c>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cluster_label'] = labels
#            lat     long  cluster_label
# 0      47.5112 -122.257              0
# 1      47.7210 -122.319              0
# 2      47.7379 -122.233              0
# 3      47.5208 -122.393              0
# 4      47.6168 -122.045              0
# ...        ...      ...            ...
# 21608  47.6993 -122.346              0
# 21609  47.5107 -122.362              0
# 21610  47.5944 -122.299              0
# 21611  47.5345 -122.069              0
# 21612  47.5941 -122.299              0
#
# [18271 rows x 3 columns]

# %%
dbs_counts = data["cluster_label"].value_counts()

dbs_counts = dbs_counts.sort_index()
print(dbs_counts)
# Out:
# -1        71
#  0     17205
#  1       137
#  2       243
#  3         9
#  4       141
#  5       186
#  6        19
#  7        37
#  8         6
#  9        19
#  10       29
#  11      101
#  12       16
#  13        8
#  14       13
#  15        5
#  16        5
#  17        5
#  18        9
#  19        7
# Name: cluster_label, dtype: int64

# %%
data = data[data['cluster_label'] != -1]
data
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2014  221900.0       3.0       1.00         1180      5650     1.0
# 1      2014  538000.0       3.0       2.25         2570      7242     2.0
# 2      2015  180000.0       2.0       1.00          770     10000     1.0
# 3      2014  604000.0       4.0       3.00         1960      5000     1.0
# 4      2015  510000.0       3.0       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608  2014  360000.0       3.0       2.50         1530      1131     3.0
# 21609  2015  400000.0       4.0       2.50         2310      5813     2.0
# 21610  2014  402101.0       2.0       0.75         1020      1350     2.0
# 21611  2015  400000.0       3.0       2.50         1600      2388     2.0
# 21612  2014  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
# Calculate the correlations
correlations = data.corrwith(data['price'])

# Display the correlations
correlations
# Out:
# date                         0.013051
# price                        1.000000
# bedrooms                     0.265690
# bathrooms                    0.416906
# sqft_living                  0.596494
# sqft_lot                     0.022080
# floors                       0.229270
# waterfront                   0.199407
# view                         0.372053
# condition                    0.084269
# grade                        0.605735
# sqft_above                   0.458273
# sqft_basement                0.317999
# yr_built                    -0.038790
# yr_renovated                 0.150297
# zipcode                      0.019994
# lat                          0.397338
# long                        -0.036110
# bedroom_to_bathroom_ratio   -0.225578
# cluster_label               -0.059137
# dtype: float64

# %%
label = data["price"]

# %%
data = data.drop(columns=['price'])
data
# Out:
#        date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      2014       3.0       1.00         1180      5650     1.0           0
# 1      2014       3.0       2.25         2570      7242     2.0           0
# 2      2015       2.0       1.00          770     10000     1.0           0
# 3      2014       4.0       3.00         1960      5000     1.0           0
# 4      2015       3.0       2.00         1680      8080     1.0           0
# ...     ...       ...        ...          ...       ...     ...         ...
# 21608  2014       3.0       2.50         1530      1131     3.0           0
# 21609  2015       4.0       2.50         2310      5813     2.0           0
# 21610  2014       2.0       0.75         1020      1350     2.0           0
# 21611  2015       3.0       2.50         1600      2388     2.0           0
# 21612  2014       2.0       0.75         1020      1076     2.0           0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

scaled_df = pd.DataFrame(scaled_data, columns =  data.columns)
scaled_df.head()
# Out:
#        date  bedrooms  bathrooms  sqft_living  sqft_lot    floors  waterfront  \
# 0 -0.696149 -0.346861  -1.482625    -1.036872 -0.440853 -0.866724   -0.058937
# 1 -0.696149 -0.346861   0.320549     0.968374  0.017783  0.969428   -0.058937
# 2  1.436474 -1.496955  -1.482625    -1.628348  0.812328 -0.866724   -0.058937
# 3 -0.696149  0.803234   1.402453     0.088374 -0.628110 -0.866724   -0.058937
# 4  1.436474 -0.346861  -0.040086    -0.315561  0.259200 -0.866724   -0.058937
#
#        view  condition     grade  sqft_above  sqft_basement  yr_built  \
# 0 -0.274061  -0.638279 -0.488528   -0.711202      -0.683739 -0.481092
# 1 -0.274061  -0.638279 -0.488528    0.882538       0.303766 -0.614574
# 2 -0.274061  -0.638279 -1.514517   -1.371237      -0.683739 -1.215244
# 3 -0.274061   2.413121 -0.488528   -0.920482       1.562835 -0.147386
# 4 -0.274061  -0.638279  0.537460    0.093717      -0.683739  0.586767
#
#    yr_renovated   zipcode       lat      long  bedroom_to_bathroom_ratio  \
# ...

# %%
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = np.array(scaled_df)
y = np.array(label)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.6749264356168013

# %%
# Make predictions on the test data
y_pred = regr.predict(X_test)

# Create a scatter plot to visualize the predictions vs. actual values
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values (Linear Regression)")


plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2)

plt.show()

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Create a Ridge regression model
ridge_model = Ridge(alpha=1.0)  # You can adjust the alpha (regularization strength)

# Fit the model to the training data
ridge_model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = ridge_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 20410253087.52872

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error


# Create a Lasso regression model
lasso_model = Lasso(alpha=4.0)  # You can adjust the alpha (regularization strength)

# Fit the model to the training data
lasso_model.fit(X_train, y_train)

# Make predictions on the test data
y_predo = lasso_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_predo)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 20410187457.5717
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.606e+13, tolerance: 9.232e+10
#   model = cd_fast.enet_coordinate_descent(

# %%
# Make predictions on the test data
y_pred = regr.predict(X_test)

# Create a scatter plot to visualize the predictions vs. actual values
plt.scatter(y_test, y_predo)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values (Linear Regression)")


plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2)

plt.show()
